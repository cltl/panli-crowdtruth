# %%
catalog.list()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'prolific_annotations_all',
#     'prolific_workers_all',
#     'preprocessed_annotations',
#     'config',
#     'crowdtruth_units',
#     'crowdtruth_workers',
#     'crowdtruth_annotations',
#     'crowdtruth_judgments',
#     'crowdtruth_jobs',
#     'prolific_workers_final',
#     'prolific_annotations_final',
#     'parameters',
#     'params:prolific_input_filepath',
#     'params:n_classes'
# ]

# %% [markdown]
# # Input data

# %%
prolific_annotations_all = catalog.load("prolific_annotations_all")
prolific_annotations_all.head()
# Out:
# [06/06/25 10:56:16] INFO     Loading data from prolific_annotations_all (CSVDataset)...         ]8;id=877433;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=787745;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                   worker_id                session_id  batch_id  list_id  \
# 0  5838532eaac091000137f09e  5f5deca7c810f60303caafbe         9       83
# 1  5838532eaac091000137f09e  5f5deca7c810f60303caafbe         9       83
# 2  5898b6e256357700011c2c6b  5f5e8ada4cddcc73212bb9e8         9       83
# 3  5898b6e256357700011c2c6b  5f5e8ada4cddcc73212bb9e8         9       83
# ...

# %%
prolific_workers_all = catalog.load("prolific_workers_all")
prolific_workers_all.head()
# Out:
# [06/06/25 10:56:29] INFO     Loading data from prolific_workers_all (CSVDataset)...             ]8;id=362818;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=528120;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                  session_id                 worker_id    status  \
# 0  5f5de7148b72aa638ec70b01  5aad226f811b2000016f6be2  APPROVED
# 1  5f5de757cc1a3d02047208ee  5e7e069af8a96f493e008ab9  APPROVED
# 2  5f5de777c9d65f6441bca85e  5c3ca0cd95d3450001358879  RETURNED
# 3  5f5de79062497c01566b2c51  5aeab7a779d448000163de2e  APPROVED
# 4  5f5de7e984523b6479e167bd  5ece98f49055f40c58e7d356  APPROVED
#
# ...

# %% [markdown]
# # CrowdTruth results

# %%
catalog.list("crowdtruth")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'crowdtruth_units',
#     'crowdtruth_workers',
#     'crowdtruth_annotations',
#     'crowdtruth_judgments',
#     'crowdtruth_jobs'
# ]

# %%
judgments = catalog.load("crowdtruth_judgments")
judgments.head()
# Out:
# [06/06/25 10:56:30] INFO     Loading data from crowdtruth_judgments (PickleDataset)...          ]8;id=674109;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=333411;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                output.answer_value  output.answer_value.count  \
# judgment
# 243653_source0            disagree                          1
# 243653_source1           uncertain                          1
# 249576_source0     partially_agree                          1
# 249576_source1               agree                          1
# 242363_source0           uncertain                          1
#
# ...

# %%
units = catalog.load("crowdtruth_units")
units.head()
# Out:
# [06/06/25 10:56:31] INFO     Loading data from crowdtruth_units (PickleDataset)...              ]8;id=115994;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=757990;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                duration  input.batch_id  input.list_id  input.n_sources  \
# unit
# 24644_source0         0               0              0                1
# 24644_source1         0               0              0                1
# 24645_source0         0               0              0                0
# 24646_source0         0               0              0                0
# ...

# %%
annotations = catalog.load("crowdtruth_annotations")
annotations.head()
# Out:
# [06/06/25 10:56:32] INFO     Loading data from crowdtruth_annotations (PickleDataset)...        ]8;id=948222;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=249886;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                  output.answer_value       aqs  aqs_initial
# agree                          22098  0.729278     0.581359
# uncertain                      28489  0.718735     0.555908
# disagree                       12969  0.545586     0.426293
# partially_agree                11073  0.252913     0.240475

# %%
workers = catalog.load("crowdtruth_workers")
workers.head()
# Out:
# [06/06/25 10:56:33] INFO     Loading data from crowdtruth_workers (PickleDataset)...            ]8;id=555832;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=134445;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                           unit  judgment  job  duration       wqs       wwa  \
# worker
# 542460e3fdf99b691e6ac927    35        35    1         0  0.559269  0.674803
# 542473a4fdf99b691fb38455    46        46    1         0  0.521195  0.640599
# 542bbe97fdf99b324f7632af    40        40    1         0  0.312899  0.504202
# 542bdb6dfdf99b324ea37c3a    41        41    1         0  0.679626  0.747652
# ...

# %%
jobs = catalog.load("crowdtruth_jobs")
jobs.head()
# Out:
#                     INFO     Loading data from crowdtruth_jobs (PickleDataset)...               ]8;id=494323;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=682259;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                   duration  judgment  judgments.per.worker  \
# job
# ../data/prolific/results/results         0     74629             37.539738
#
#                                   output.answer_value.annotations  \
# job
# ../data/prolific/results/results                         9.999866
#
#                                   output.answer_value.unique_annotations  \
# job
# ...

# %% [markdown]
# # After selection

# %%
prolific_annotations_final = catalog.load("prolific_annotations_final")
prolific_annotations_final.head()
# Out:
# [06/06/25 10:56:34] INFO     Loading data from prolific_annotations_final (CSVDataset)...       ]8;id=905715;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=367023;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                   worker_id                session_id  batch_id  list_id  \
# 0  5838532eaac091000137f09e  5f5deca7c810f60303caafbe         9       83
# 1  5838532eaac091000137f09e  5f5deca7c810f60303caafbe         9       83
# 2  5898b6e256357700011c2c6b  5f5e8ada4cddcc73212bb9e8         9       83
# 3  5898b6e256357700011c2c6b  5f5e8ada4cddcc73212bb9e8         9       83
# ...

# %%
prolific_workers_final = catalog.load("prolific_workers_final")
prolific_workers_final.head()
# Out:
# [06/06/25 10:56:35] INFO     Loading data from prolific_workers_final (CSVDataset)...           ]8;id=576265;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=677185;file://C:\Users\Jean\AppData\Local\pypoetry\Cache\virtualenvs\panli-crowdtruth-XrO6fEzZ-py3.11\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                  session_id                 worker_id    status  \
# 0  5f5deca7c810f60303caafbe  5838532eaac091000137f09e  APPROVED
# 1  5f5e8ada4cddcc73212bb9e8  5898b6e256357700011c2c6b  APPROVED
# 2  5f5dec01b2a8ef6474a4c1e1  5b0d9494e9270900013bd5a5  APPROVED
# 3  5f5dec325bbf4b640840ece7  5dc93b9a575da16530499583  APPROVED
# 4  5f5de9f2bb6627025a46383c  5e234d6a25a4d06041453bb0  APPROVED
#
# ...
